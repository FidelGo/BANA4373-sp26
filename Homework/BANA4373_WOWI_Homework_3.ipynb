# %% [markdown]
# # BANA 4373 — Homework 3
# ## Building a WOWI Economic Data Agent
#
# **Course:** ECON 4370 – Applied Data Tools for Economics and Business
# **Instructor:** Dr. Fidel Gonzalez
# **Assignment:** Homework 3
# **Topic:** AI Agents and Economic Data
#
# ---
#
# # Overview
#
# In this assignment you will build a simple **economic data agent** that can answer questions using real economic datasets.
#
# The agent will follow a framework we introduced in class called the **WOWI framework**:
#
# ### WOWI Framework
#
# **WHAT → OBTAIN → WORK → INTERPRET**
#
# | Step | Meaning |
# |-----|------|
# | **WHAT** | Understand the user’s question |
# | **OBTAIN** | Retrieve the necessary data |
# | **WORK** | Analyze the data using tools |
# | **INTERPRET** | Explain the economic meaning |
#
# This framework mirrors the workflow used by economists and data analysts:
#
# **Question → Data → Analysis → Interpretation**
#
# Your agent will retrieve data from real sources such as:
#
# - **FRED (Federal Reserve Economic Data)**
# - **U.S. Census American Community Survey (ACS)**
#
# ---
#
# # Learning Objectives
#
# By completing this assignment you will learn how to:
#
# - Use **APIs** to retrieve real-world economic data
# - Explore and identify relevant **economic data series**
# - Build simple **data analysis tools**
# - Understand how **AI agents interact with tools**
# - Interpret economic results like an applied economist
#
# ---
#
# # What you must do
#
# ### Part A — API keys
#
# You must obtain and use:
#
# - an **OpenAI API key**
# - a **FRED API key**
# - a **Census API key**
#
# These keys allow your agent to:
# - interpret user questions
# - retrieve macroeconomic data
# - retrieve socioeconomic data
#
# ---
#
# ### Part B — Data dictionaries
#
# You will start with:
#
# - **2 example FRED series**
# - **2 example ACS variables**
#
# You must add:
#
# - **2 more FRED series**
# - **2 more ACS variables**
#
# So your final dictionaries must contain **at least 4 series or variables from each source**.
#
# Important:
# The example variables provided in the notebook **may be used in your analysis**, but they **do not count toward your required additions**.
#
# ---
#
# ### Part C — Tools
#
# You are given **three starter tools**:
#
# 1. A **FRED data retrieval tool**
# 2. A **Census ACS data retrieval tool**
# 3. A **plotting tool**
#
# You must build **two additional tools** of your own.
#
# These tools should help your agent **analyze or transform the data**.
#
# Examples include:
#
# - correlation
# - moving averages
# - summary statistics
# - ranking states
# - differences between variables
#
# An example tool will be shown in the notebook for guidance, but **you may not use that example as one of your required tools**.
#
# ---
#
# ### Part D — Agents
#
# You will work with **two types of workflows**:
#
# 1. A **scripted example** from class
# 2. A **WOWI agent**
#
# The scripted example follows fixed instructions.
#
# The WOWI agent is more flexible because it:
#
# - interprets the question
# - decides what data to obtain
# - selects tools
# - produces an answer
#
# ---
#
# ### Part E — Demo runs
#
# You must complete **10 demo runs** using your **WOWI agent**.
#
# Across your demo runs you must:
#
# - use **both data sources** (FRED and ACS)
# - use **both of your custom tools**
# - write a short interpretation of the results
#
# Each interpretation should explain:
#
# - what the agent chose to do
# - what the output shows
# - what the result means economically
#
# ---
#
# # What you must turn in
#
# You must submit **one completed Jupyter Notebook (.ipynb file)**.
#
# Before submitting, make sure that:
#
# - all required sections are completed
# - your two tools are implemented
# - all **10 demo runs** are included
# - each run includes an **interpretation**
# - the notebook runs from top to bottom without major errors
#
# Upload the notebook to **Blackboard**.
#
# ---
#
# # Important note
#
# This notebook contains:
#
# - starter code
# - example sections
# - **TODO sections** that you must complete
#
# Work carefully through each section. The assignment is designed to be **challenging but very manageable if you proceed step by step**.

# %%
# Student Information

student_name = input("Enter your full name: ")
print("Student:", student_name)

# %% [markdown]
# ## Progress Checklist
#
# Before submitting, make sure you have completed:
#
# - [ ] API keys entered
# - [ ] Added 2 new FRED series
# - [ ] Added 2 new ACS variables
# - [ ] Implemented Tool 4
# - [ ] Implemented Tool 5
# - [ ] Ran the scripted example
# - [ ] Completed 10 demo runs
# - [ ] Written interpretations for each run
# - [ ] Completed the reflection section

# %% [markdown]
# # Part 1 — Obtain API Keys
#
# You must obtain:
#
# • OpenAI API key
# • FRED API key
# • Census API key
#
# FRED API: https://fred.stlouisfed.org/docs/api/api_key.html
# Census API: https://api.census.gov/data/key_signup.html

# %%
from getpass import getpass
import os

os.environ["OPENAI_API_KEY"] = getpass("OpenAI key: ")
os.environ["FRED_API_KEY"] = getpass("FRED key: ")
os.environ["CENSUS_API_KEY"] = getpass("Census key: ")

print("Keys loaded.")

# %% [markdown]
# # Part 2 — Data Dictionaries
#
# You are given **two example variables from each source**.
#
# You may use them in analysis, but **they DO NOT count toward the required additions**.
#
# You must add:
#
# • **2 additional FRED series**
# • **2 additional ACS variables**

# %%
# Example FRED series (provided)

FRED_SERIES = {
    "inflation": "CPIAUCSL",
    "unemployment": "UNRATE"
}

# TODO: Add two additional FRED series below
# Example ideas: GDP, federal funds rate, oil price, wages

# %%
# Example ACS variables (provided)

ACS_VARIABLES = {
    "median_income": "B19013_001E",
    "population": "B01003_001E"
}

# TODO: Add two additional ACS variables below
# Example ideas: poverty, home value, rent, education

# %% [markdown]
# # Part 3 — Provided Tools
# You are given three starter tools.

# %%
from fredapi import Fred
import pandas as pd

fred = Fred(api_key=os.environ["FRED_API_KEY"])

def get_fred_series(series_id):
    s = fred.get_series(series_id)
    s.index = pd.to_datetime(s.index)
    return s

# %%
import requests

def get_acs_state_data(variable, year=2022):

    key = os.environ["CENSUS_API_KEY"]
    url = f"https://api.census.gov/data/{year}/acs/acs1"

    params = {
        "get": f"NAME,{variable}",
        "for": "state:*",
        "key": key
    }

    r = requests.get(url, params=params)
    data = r.json()

    df = pd.DataFrame(data[1:], columns=data[0])
    df[variable] = pd.to_numeric(df[variable])

    return df

# %%
import plotly.express as px

def plot_data(df, x, y, title):
    fig = px.line(df, x=x, y=y, title=title)
    fig.show()

# %% [markdown]
# # Part 4 — Scripted Example
#
# Run this example from class.
#
# This is a **scripted workflow**, not a flexible agent.

# %%
s1 = get_fred_series("CPIAUCSL")
s2 = get_fred_series("UNRATE")

df = pd.concat([s1,s2], axis=1)
df.columns=["inflation","unemployment"]

df.plot(title="Scripted Example")

# %% [markdown]
# ### Reflection
# Why is the example above **not a flexible AI agent**?

# %% [markdown]
# # Part 5 — Create Two New Tools
#
# Example tool (DO NOT USE):
#
# ```
# def growth_rate(series):
#     return series.pct_change()*100
# ```
#
# Create **two different tools** below.

# %%
def tool4(data):
    # TODO: create your tool
    pass

# %%
def tool5(data):
    # TODO: create your tool
    pass

# %% [markdown]
# # Part 6 — WOWI Agent
#
# The agent follows:
#
# WHAT → OBTAIN → WORK → INTERPRET

# %%
from openai import OpenAI
import json

client = OpenAI()

def plan(question):

    prompt = f'''
Return JSON:

source: fred or acs
concepts: variables
task: compare or describe

Question: {question}
'''

    response = client.chat.completions.create(
        model="gpt-4.1-mini",
        messages=[{"role":"user","content":prompt}]
    )

    text=response.choices[0].message.content

    return json.loads(text)

# %% [markdown]
# # Part 7 — Example WOWI Run (Do NOT count)

# %%
example = plan("Compare inflation and unemployment")
example

# %% [markdown]
# # Part 8 — 10 Demo Runs
#
# You must run your agent **10 times**.
#
# Requirements:
#
# • Use both data sources
# • Use both custom tools
# • Provide interpretation

# %% [markdown]
# ## Demo Run 1

# %%
question_1 = "Replace this with your question"

result_1 = plan(question_1)
result_1

# %% [markdown]
# Interpretation here.

# %% [markdown]
# ## Demo Run 2

# %%
question_2 = "Replace this with your question"

result_2 = plan(question_2)
result_2

# %% [markdown]
# Interpretation here.

# %% [markdown]
# ## Demo Run 3

# %%
question_3 = "Replace this with your question"

result_3 = plan(question_3)
result_3

# %% [markdown]
# Interpretation here.

# %% [markdown]
# ## Demo Run 4

# %%
question_4 = "Replace this with your question"

result_4 = plan(question_4)
result_4

# %% [markdown]
# Interpretation here.

# %% [markdown]
# ## Demo Run 5

# %%
question_5 = "Replace this with your question"

result_5 = plan(question_5)
result_5

# %% [markdown]
# Interpretation here.

# %% [markdown]
# ## Demo Run 6

# %%
question_6 = "Replace this with your question"

result_6 = plan(question_6)
result_6

# %% [markdown]
# Interpretation here.

# %% [markdown]
# ## Demo Run 7

# %%
question_7 = "Replace this with your question"

result_7 = plan(question_7)
result_7

# %% [markdown]
# Interpretation here.

# %% [markdown]
# ## Demo Run 8

# %%
question_8 = "Replace this with your question"

result_8 = plan(question_8)
result_8

# %% [markdown]
# Interpretation here.

# %% [markdown]
# ## Demo Run 9

# %%
question_9 = "Replace this with your question"

result_9 = plan(question_9)
result_9

# %% [markdown]
# Interpretation here.

# %% [markdown]
# ## Demo Run 10

# %%
question_10 = "Replace this with your question"

result_10 = plan(question_10)
result_10

# %% [markdown]
# Interpretation here.

# %% [markdown]
# # Final Reflection
#
# 1. How did you find additional FRED series?
# 2. How did you find ACS variables?
# 3. What do your tools do?
# 4. Difference between scripted workflow and WOWI agent?
